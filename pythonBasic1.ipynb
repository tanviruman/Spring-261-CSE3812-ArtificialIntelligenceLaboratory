# %% [markdown]
# My first python code

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
a = 'hello world'
print(a, type(a))
a = "hello world"
print(a)
# Out:
# hello world <class 'str'>
# hello world

# %%
a = 5
b = 10

print(a, b)
# Out:
# 5 10

# %%
#another way

a, b = 5, 10
print(a, b)
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>
