# %% [markdown]
# My first python code

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
a = 'hello world'
print(a, type(a))
a = "hello world"
print(a)
# Out:
# hello world <class 'str'>
# hello world
